# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Observable trends
# 1.In the northern hemisphere the temperature is negatively corerelated with the latitude
# 2.In the southern hemisphere the temperature is positively corerelated with the latitude
# 3.The wind speed is equally distibuted with respect to the latitude

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime


# Import API key
from config import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['hobart',
#  'gorontalo',
#  'komsomolskiy',
#  'vaini',
#  'mercedes',
#  'saint-georges',
#  'amderma',
#  'saint-philippe',
#  'rundu',
#  'hermon',
#  'hermanus',
#  'ushuaia',
#  'bredasdorp',
#  'dunedin',
#  'nizhneyansk',
#  'lorengau',
#  'kyra',
#  'safwah',
#  'kodiak',
#  'constitucion',
#  'ternate',
#  'comodoro rivadavia',
#  'punta arenas',
#  'dawei',
#  'fairbanks',
#  'rikitea',
#  'lebu',
#  'babanusah',
#  'saint-pierre',
#  'anjar',
#  'cape town',
#  'tuatapere',
#  'ambovombe',
#  'namatanai',
#  'bagan',
#  'codrington',
#  'albany',
#  'xuzhou',
#  'khromtau',
#  'bethel',
#  'kyshtovka',
#  'taolanaro',
#  'jamestown',
#  'tsihombe',
#  'marawi',
#  'sentyabrskiy',
#  'sitka',
#  'hamilton',
#  'puerto ayora',
#  'port elizabeth',
#  'churapcha',
#  'rorvik',
#  'dingle',
#  'utiroa',
#  'butaritari',
#  'ngukurr',
#  'storebo',
#  'marcona',
#  'darnah',
#  'los llanos de aridane',
#  'sept-iles',
#  'cabo san lucas',
#  'hanzhong',
#  'fengrun',
#  'port alfred',
#  'castro',
#  'bud',
#  'manavgat',
#  'basar',
#  'rostovka',
#  'andenes',
#  'brae',
#  'thompson',
#  'jieshi',
#  'fortuna',
#  'pangnirtung',
#  'belushya guba',
#  'east london',
#  'illoqqortoormiut',
#  'sao filipe',
#  'sorong',
#  'arraial do cabo',
#  'barrow',
#  'vaitupu',
#  'phayao',
#  'quito',
#  'nemuro',
#  'sao gabriel da cachoeira',
#  'havelock',
#  'ilulissat',
#  'tarudant',
#  'tura',
#  'svetlyy',
#  'mahajanga',
#  'killam',
#  'vychegodskiy',
#  'ribeira grande',
#  'lasa',
#  'mataura',
#  'khatanga',
#  'saurimo',
#  'tuktoyaktuk',
#  'attawapiskat',
#  'mehamn',
#  'belaya glina',
#  'saldanha',
#  'norman wells',
#  'namibe',
#  'gulbene',
#  'hualmay',
#  'urumqi',
#  'geraldton',
#  'bluff',
#  'hithadhoo',
#  'nikolskoye',
#  'ponnani',
#  'qaanaaq',
#  'gazojak',
#  'tiksi',
#  'guarapari',
#  'ponta do sol',
#  'kapaa',
#  'port hedland',
#  'togur',
#  'atuona',
#  'yelnya',
#  'port-cartier',
#  'dikson',
#  'yumen',
#  'altay',
#  'yellowknife',
#  'pisco',
#  'chabahar',
#  'sosnogorsk',
#  'avarua',
#  'alta gracia',
#  'san pedro',
#  'iwaki',
#  'kaitangata',
#  'acari',
#  'strelka',
#  'vanimo',
#  'ilhabela',
#  'mys shmidta',
#  'salalah',
#  'tateyama',
#  'marshfield',
#  'samalaeulu',
#  'lolua',
#  'koumac',
#  'barentsburg',
#  'lagoa',
#  'poro',
#  'saskylakh',
#  'barguzin',
#  'nelson bay',
#  'new norfolk',
#  'mersing',
#  'birao',
#  'cockburn town',
#  'limbang',
#  'meulaboh',
#  'sawakin',
#  'faanui',
#  'sucua',
#  'novo cruzeiro',
#  'severo-kurilsk',
#  'souillac',
#  'pelotas',
#  'san patricio',
#  'pemberton',
#  'mullaitivu',
#  'faya',
#  'nanganga',
#  'airai',
#  'carnarvon',
#  'ulaanbaatar',
#  'busselton',
#  'tasiilaq',
#  'malakal',
#  'conde',
#  'hilo',
#  'mahibadhoo',
#  'berlevag',
#  'kahului',
#  'nanortalik',
#  'krasnyy chikoy',
#  'muros',
#  'jacareacanga',
#  'olavarria',
#  'kudahuvadhoo',
#  'naryan-mar',
#  'gornyy',
#  'kruisfontein',
#  'ballina',
#  'ocos',
#  'tamiahua',
#  'chokurdakh',
#  'kembe',
#  'boa vista',
#  'energetik',
#  'paradwip',
#  'zarinsk',
#  'upernavik',
#  'leeton',
#  'georgetown',
#  'cotonou',
#  'yar-sale',
#  'suoyarvi',
#  'rumonge',
#  'farmington',
#  'mirandela',
#  'klyuchi',
#  'chuy',
#  'cortland',
#  'hilliard',
#  'qaqortoq',
#  'longyearbyen',
#  'mahebourg',
#  'luganville',
#  'kampot',
#  'kavaratti',
#  'neuquen',
#  'rafai',
#  'bubaque',
#  'koslan',
#  'sao luis do quitunde',
#  'mweka',
#  'samusu',
#  'cherskiy',
#  'lucapa',
#  'mataram',
#  'maniitsoq',
#  'vao',
#  'port blair',
#  'palabuhanratu',
#  'qasigiannguit',
#  'camana',
#  'saint-denis',
#  'burnie',
#  'talaya',
#  'butembo',
#  'burica',
#  'rumboci',
#  'mergui',
#  'toamasina',
#  'hirara',
#  'dukat',
#  'vardo',
#  'san isidro',
#  'voh',
#  'grindavik',
#  'moree',
#  'bocaranga',
#  'praia da vitoria',
#  'pathein',
#  'port hardy',
#  'catalina',
#  'hasaki',
#  'victoria',
#  'la union',
#  'havre-saint-pierre',
#  'bonthe',
#  'narsaq',
#  'umzimvubu',
#  'arlit',
#  'san jose',
#  'asau',
#  'tripoli',
#  'mutsamudu',
#  'misratah',
#  'mount gambier',
#  'slapanice',
#  'margate',
#  'touros',
#  'port hawkesbury',
#  'ivankiv',
#  'benjamin constant',
#  'haikou',
#  'palora',
#  'nome',
#  'coahuayana',
#  'paoua',
#  'bambous virieux',
#  'pacific grove',
#  'makakilo city',
#  'anahuac',
#  'aguilas',
#  'prainha',
#  'guamuchil',
#  'birjand',
#  'waitati',
#  'middelburg',
#  'remedios',
#  'chimoio',
#  'haines junction',
#  'bonavista',
#  'harnosand',
#  'benguela',
#  'ormara',
#  'itoman',
#  'tabivere',
#  'north platte',
#  'westport',
#  'kavieng',
#  'vila velha',
#  'oksovskiy',
#  'krasne',
#  'verkhnyaya inta',
#  'vanavara',
#  'saleaula',
#  'sorvag',
#  'alyangula',
#  'grand river south east',
#  'khanpur',
#  'sioux lookout',
#  'secunda',
#  'bereda',
#  'guelengdeng',
#  'eydhafushi',
#  'unecha',
#  'baruun-urt',
#  'ancud',
#  'bathsheba',
#  'port keats',
#  'half moon bay',
#  'nantucket',
#  'christchurch',
#  'nioro',
#  'iqaluit',
#  'beringovskiy',
#  'isangel',
#  'la grande',
#  'beira',
#  'ust-kamchatsk',
#  'mapiripan',
#  'olafsvik',
#  'dawlatabad',
#  'halden',
#  'weiser',
#  'creston',
#  'katangli',
#  'paredon',
#  'mishkino',
#  'kasongo-lunda',
#  'dicabisagan',
#  'mitzic',
#  'srandakan',
#  'banjar',
#  'prince rupert',
#  'steamboat springs',
#  'bilma',
#  'winona',
#  'lewiston',
#  'banda aceh',
#  'bataipora',
#  'hovd',
#  'leh',
#  'raudeberg',
#  'siteki',
#  'ostrovnoy',
#  'lhokseumawe',
#  'derzhavinsk',
#  'camacha',
#  'sarlat-la-caneda',
#  'carutapera',
#  'la ronge',
#  'houston',
#  'mikhaylovka',
#  'coquimbo',
#  'tumannyy',
#  'nyurba',
#  'sao paulo de olivenca',
#  'sur',
#  'shangrao',
#  'alice springs',
#  'kloulklubed',
#  'dogondoutchi',
#  'awbari',
#  'provideniya',
#  'malaut',
#  'buala',
#  'hay river',
#  'dutlwe',
#  'te anau',
#  'fiumicino',
#  'kamenka',
#  'malanje',
#  'kaeo',
#  'samarai',
#  'anadyr',
#  'sao joao da barra',
#  'ferrol',
#  'shubarkuduk',
#  'oussouye',
#  'borlange',
#  'arys',
#  'puerto escondido',
#  'hobyo',
#  'kieta',
#  'shenjiamen',
#  'tabuleiro do norte',
#  'mazamari',
#  'nova olinda do norte',
#  'oktyabrskiy',
#  'windhoek',
#  'kandri',
#  'dolores',
#  'inirida',
#  'kedrovyy',
#  'kidal',
#  'midleton',
#  'necochea',
#  'araouane',
#  'ijaki',
#  'rossland',
#  'manitouwadge',
#  'sakrand',
#  'klaksvik',
#  'viedma',
#  'rosetta',
#  'zalantun',
#  'elat',
#  'aykhal',
#  'manzil jamil',
#  'saint anthony',
#  'clyde river',
#  'ahipara',
#  'gamba',
#  'sambava',
#  'lakes entrance',
#  'flinders',
#  'topolobampo',
#  'wukari',
#  'cuiluan',
#  'moindou',
#  'graham',
#  'caravelas',
#  'novovasylivka',
#  'sawtell',
#  'vestmannaeyjar',
#  'auki',
#  'bridgeport',
#  'loubomo',
#  'elko',
#  'egvekinot',
#  'beloha',
#  'batagay-alyta',
#  'torbay',
#  'baykit',
#  'coffs harbour',
#  'mar del plata',
#  'sembe',
#  'rawson',
#  'cervo',
#  'dao',
#  'yizheng',
#  'challapata',
#  'broome',
#  'yinchuan',
#  'hendersonville',
#  'nayoro',
#  'kapit',
#  'breyten',
#  'richards bay',
#  'jacqueville',
#  'gebre guracha',
#  'saryozek',
#  'hervey bay',
#  'tsiroanomandidy',
#  'maun',
#  'rio grande',
#  'son tay',
#  'naze',
#  'san cristobal',
#  'chumikan',
#  'aflu',
#  'sao miguel do oeste',
#  'luwuk',
#  'narrabri',
#  'athabasca',
#  'atasu',
#  'port macquarie',
#  'yeletskiy',
#  'nautla',
#  'araguacu',
#  'praya',
#  'liwale',
#  'kupang',
#  'karasjok',
#  'taywarah',
#  'pevek',
#  'grand gaube',
#  'spartanburg',
#  'tessalit',
#  'kirakira',
#  'turukhansk',
#  'hami',
#  'gallup',
#  'izhma',
#  'woodward',
#  'eyl',
#  'bourail',
#  'yangjiang',
#  'tarazona',
#  'mareeba',
#  'okoneshnikovo',
#  'jeremie',
#  'bengkulu',
#  'abha',
#  'port moresby',
#  'deputatskiy',
#  'pangkalanbuun',
#  'nabul',
#  'chicama',
#  'lompoc',
#  'tual',
#  'guajara-mirim',
#  'katsuura',
#  'shimoda',
#  'kharitonovo',
#  'senmonorom',
#  'markova',
#  'bargal',
#  'el balyana',
#  'port lincoln',
#  'esperance',
#  'waingapu',
#  'moron',
#  'ondorhaan',
#  'yarmouth',
#  'saint-priest',
#  'smyshlyayevka',
#  'fairfield',
#  'labutta',
#  'muroto',
#  'along',
#  'bhadrachalam',
#  'shambu',
#  'sangar',
#  'alofi',
#  'sabha',
#  'the pas',
#  'marzuq',
#  'lavrentiya',
#  'tubay',
#  'mahon',
#  'mokrous',
#  'santa cruz',
#  'kiunga',
#  'campos do jordao',
#  'payo',
#  'riosucio',
#  'rabo de peixe',
#  'padang',
#  'kolda',
#  'severodvinsk',
#  'karaul',
#  'port pirie',
#  'sibu',
#  'laurel',
#  'ngama',
#  'san antonio',
#  'imbituba',
#  'kisangani',
#  'healdsburg',
#  'tautira',
#  'naryshkino',
#  'lufilufi',
#  'terra santa',
#  'tubruq',
#  'gobabis',
#  'broken hill',
#  'biak',
#  'tevriz',
#  'mayo',
#  'nishihara',
#  'vila franca do campo',
#  'charyshskoye',
#  'nuuk',
#  'qiqihar',
#  'laguna',
#  'mitchell',
#  'silvan',
#  'chippewa falls',
#  'north vernon',
#  'assiniboia',
#  'batticaloa',
#  'suntar',
#  'bhadra',
#  'rawah',
#  'soyo',
#  'guiong',
#  'palmer',
#  'xifeng',
#  'fare',
#  'ati',
#  'kutulik',
#  'coihaique',
#  'grand-santi',
#  'puerto del rosario',
#  'yulara',
#  'aksu',
#  'saint george',
#  'maraa',
#  'tazovskiy',
#  'vukovar',
#  'krasnoselkup',
#  'jalu',
#  'doha',
#  'coruripe',
#  'margherita',
#  'kazalinsk',
#  'siuna',
#  'shingu',
#  'ca mau',
#  'tezu',
#  'arrecife',
#  'shihezi',
#  'linhares',
#  'ahuimanu',
#  'taksimo',
#  'mbanza-ngungu',
#  'husavik',
#  'campbell river',
#  'shiroishi',
#  'terrace',
#  'haibowan',
#  'arequipa',
#  'banfora',
#  'vestbygda',
#  'kaifeng',
#  'teguise']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
city_number = 0

# set up lists to hold reponse info
lat = []
long = []
temp = []
cloudiness = []
windspeed = []
humidity = []
city_name = []
country = []

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + city).json()


for city in cities:
    city_number = city_number + 1
    print(f"Fetching data for {city_number}: {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        cloudiness.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        humidity.append(response["main"]["humidity"])
        city_name.append(response["name"])
        long.append(response["coord"]["lon"])
        country.append(response['sys']['country'])
                
    except:
        print("Response not found")
# Out:
# Fetching data for 1: hobart
# Fetching data for 2: gorontalo
# Fetching data for 3: komsomolskiy
# Fetching data for 4: vaini
# Fetching data for 5: mercedes
# Fetching data for 6: saint-georges
# Fetching data for 7: amderma
# Response not found
# Fetching data for 8: saint-philippe
# Fetching data for 9: rundu
# Fetching data for 10: hermon
# Fetching data for 11: hermanus
# Fetching data for 12: ushuaia
# Fetching data for 13: bredasdorp
# Fetching data for 14: dunedin
# Fetching data for 15: nizhneyansk
# Response not found
# Fetching data for 16: lorengau
# Fetching data for 17: kyra
# Fetching data for 18: safwah
# Response not found
# Fetching data for 19: kodiak
# Fetching data for 20: constitucion
# Fetching data for 21: ternate
# Fetching data for 22: comodoro rivadavia
# Fetching data for 23: punta arenas
# Fetching data for 24: dawei
# Fetching data for 25: fairbanks
# Fetching data for 26: rikitea
# Fetching data for 27: lebu
# Fetching data for 28: babanusah
# Response not found
# Fetching data for 29: saint-pierre
# Fetching data for 30: anjar
# Fetching data for 31: cape town
# Fetching data for 32: tuatapere
# Fetching data for 33: ambovombe
# Fetching data for 34: namatanai
# Fetching data for 35: bagan
# Fetching data for 36: codrington
# Fetching data for 37: albany
# Fetching data for 38: xuzhou
# Fetching data for 39: khromtau
# Fetching data for 40: bethel
# Fetching data for 41: kyshtovka
# Fetching data for 42: taolanaro
# Response not found
# Fetching data for 43: jamestown
# Fetching data for 44: tsihombe
# Response not found
# Fetching data for 45: marawi
# Fetching data for 46: sentyabrskiy
# Response not found
# Fetching data for 47: sitka
# Fetching data for 48: hamilton
# Fetching data for 49: puerto ayora
# Fetching data for 50: port elizabeth
# Fetching data for 51: churapcha
# Fetching data for 52: rorvik
# Fetching data for 53: dingle
# Fetching data for 54: utiroa
# Response not found
# Fetching data for 55: butaritari
# Fetching data for 56: ngukurr
# Response not found
# Fetching data for 57: storebo
# Fetching data for 58: marcona
# Response not found
# Fetching data for 59: darnah
# Fetching data for 60: los llanos de aridane
# Fetching data for 61: sept-iles
# Fetching data for 62: cabo san lucas
# Fetching data for 63: hanzhong
# Fetching data for 64: fengrun
# Fetching data for 65: port alfred
# Fetching data for 66: castro
# Fetching data for 67: bud
# Fetching data for 68: manavgat
# Fetching data for 69: basar
# Fetching data for 70: rostovka
# Fetching data for 71: andenes
# Fetching data for 72: brae
# Fetching data for 73: thompson
# Fetching data for 74: jieshi
# Fetching data for 75: fortuna
# Fetching data for 76: pangnirtung
# Fetching data for 77: belushya guba
# Response not found
# Fetching data for 78: east london
# Fetching data for 79: illoqqortoormiut
# Response not found
# Fetching data for 80: sao filipe
# Fetching data for 81: sorong
# Fetching data for 82: arraial do cabo
# Fetching data for 83: barrow
# Fetching data for 84: vaitupu
# Response not found
# Fetching data for 85: phayao
# Fetching data for 86: quito
# Fetching data for 87: nemuro
# Fetching data for 88: sao gabriel da cachoeira
# Fetching data for 89: havelock
# Fetching data for 90: ilulissat
# Fetching data for 91: tarudant
# Response not found
# Fetching data for 92: tura
# Fetching data for 93: svetlyy
# Fetching data for 94: mahajanga
# Fetching data for 95: killam
# Fetching data for 96: vychegodskiy
# Fetching data for 97: ribeira grande
# Fetching data for 98: lasa
# Fetching data for 99: mataura
# Fetching data for 100: khatanga
# Fetching data for 101: saurimo
# Fetching data for 102: tuktoyaktuk
# Fetching data for 103: attawapiskat
# Response not found
# Fetching data for 104: mehamn
# Fetching data for 105: belaya glina
# Fetching data for 106: saldanha
# Fetching data for 107: norman wells
# Fetching data for 108: namibe
# Fetching data for 109: gulbene
# Fetching data for 110: hualmay
# Fetching data for 111: urumqi
# Fetching data for 112: geraldton
# Fetching data for 113: bluff
# Fetching data for 114: hithadhoo
# Fetching data for 115: nikolskoye
# Fetching data for 116: ponnani
# Fetching data for 117: qaanaaq
# Fetching data for 118: gazojak
# Fetching data for 119: tiksi
# Fetching data for 120: guarapari
# Fetching data for 121: ponta do sol
# Fetching data for 122: kapaa
# Fetching data for 123: port hedland
# Fetching data for 124: togur
# Fetching data for 125: atuona
# Fetching data for 126: yelnya
# Fetching data for 127: port-cartier
# Fetching data for 128: dikson
# Fetching data for 129: yumen
# Fetching data for 130: altay
# Fetching data for 131: yellowknife
# Fetching data for 132: pisco
# Fetching data for 133: chabahar
# Fetching data for 134: sosnogorsk
# Fetching data for 135: avarua
# Fetching data for 136: alta gracia
# Fetching data for 137: san pedro
# Fetching data for 138: iwaki
# Fetching data for 139: kaitangata
# Fetching data for 140: acari
# Fetching data for 141: strelka
# Fetching data for 142: vanimo
# Fetching data for 143: ilhabela
# Fetching data for 144: mys shmidta
# Response not found
# Fetching data for 145: salalah
# Fetching data for 146: tateyama
# Fetching data for 147: marshfield
# Fetching data for 148: samalaeulu
# Response not found
# Fetching data for 149: lolua
# Response not found
# Fetching data for 150: koumac
# Fetching data for 151: barentsburg
# Response not found
# Fetching data for 152: lagoa
# Fetching data for 153: poro
# Fetching data for 154: saskylakh
# Fetching data for 155: barguzin
# Fetching data for 156: nelson bay
# Fetching data for 157: new norfolk
# Fetching data for 158: mersing
# Fetching data for 159: birao
# Fetching data for 160: cockburn town
# Fetching data for 161: limbang
# Fetching data for 162: meulaboh
# Fetching data for 163: sawakin
# Fetching data for 164: faanui
# Fetching data for 165: sucua
# Fetching data for 166: novo cruzeiro
# Fetching data for 167: severo-kurilsk
# Fetching data for 168: souillac
# Fetching data for 169: pelotas
# Fetching data for 170: san patricio
# Fetching data for 171: pemberton
# Fetching data for 172: mullaitivu
# Response not found
# Fetching data for 173: faya
# Fetching data for 174: nanganga
# Fetching data for 175: airai
# Fetching data for 176: carnarvon
# Fetching data for 177: ulaanbaatar
# Fetching data for 178: busselton
# Fetching data for 179: tasiilaq
# Fetching data for 180: malakal
# Fetching data for 181: conde
# Fetching data for 182: hilo
# Fetching data for 183: mahibadhoo
# Fetching data for 184: berlevag
# Fetching data for 185: kahului
# Fetching data for 186: nanortalik
# Fetching data for 187: krasnyy chikoy
# Fetching data for 188: muros
# Fetching data for 189: jacareacanga
# Fetching data for 190: olavarria
# Fetching data for 191: kudahuvadhoo
# Fetching data for 192: naryan-mar
# Fetching data for 193: gornyy
# Fetching data for 194: kruisfontein
# Fetching data for 195: ballina
# Fetching data for 196: ocos
# Fetching data for 197: tamiahua
# Fetching data for 198: chokurdakh
# Fetching data for 199: kembe
# Fetching data for 200: boa vista
# Fetching data for 201: energetik
# Fetching data for 202: paradwip
# Response not found
# Fetching data for 203: zarinsk
# Fetching data for 204: upernavik
# Fetching data for 205: leeton
# Fetching data for 206: georgetown
# Fetching data for 207: cotonou
# Fetching data for 208: yar-sale
# Fetching data for 209: suoyarvi
# Fetching data for 210: rumonge
# Fetching data for 211: farmington
# Fetching data for 212: mirandela
# Fetching data for 213: klyuchi
# Fetching data for 214: chuy
# Fetching data for 215: cortland
# Fetching data for 216: hilliard
# Fetching data for 217: qaqortoq
# Fetching data for 218: longyearbyen
# Fetching data for 219: mahebourg
# Fetching data for 220: luganville
# Fetching data for 221: kampot
# Fetching data for 222: kavaratti
# Fetching data for 223: neuquen
# Fetching data for 224: rafai
# Fetching data for 225: bubaque
# Fetching data for 226: koslan
# Fetching data for 227: sao luis do quitunde
# Fetching data for 228: mweka
# Fetching data for 229: samusu
# Response not found
# Fetching data for 230: cherskiy
# Fetching data for 231: lucapa
# Fetching data for 232: mataram
# Fetching data for 233: maniitsoq
# Fetching data for 234: vao
# Fetching data for 235: port blair
# Fetching data for 236: palabuhanratu
# Response not found
# Fetching data for 237: qasigiannguit
# Fetching data for 238: camana
# Fetching data for 239: saint-denis
# Fetching data for 240: burnie
# Fetching data for 241: talaya
# Fetching data for 242: butembo
# Fetching data for 243: burica
# Response not found
# Fetching data for 244: rumboci
# Fetching data for 245: mergui
# Response not found
# Fetching data for 246: toamasina
# Fetching data for 247: hirara
# Fetching data for 248: dukat
# Fetching data for 249: vardo
# Fetching data for 250: san isidro
# Fetching data for 251: voh
# Fetching data for 252: grindavik
# Fetching data for 253: moree
# Fetching data for 254: bocaranga
# Response not found
# Fetching data for 255: praia da vitoria
# Fetching data for 256: pathein
# Fetching data for 257: port hardy
# Fetching data for 258: catalina
# Fetching data for 259: hasaki
# Fetching data for 260: victoria
# Fetching data for 261: la union
# Fetching data for 262: havre-saint-pierre
# Fetching data for 263: bonthe
# Fetching data for 264: narsaq
# Fetching data for 265: umzimvubu
# Response not found
# Fetching data for 266: arlit
# Fetching data for 267: san jose
# Fetching data for 268: asau
# Fetching data for 269: tripoli
# Fetching data for 270: mutsamudu
# Response not found
# Fetching data for 271: misratah
# Fetching data for 272: mount gambier
# Fetching data for 273: slapanice
# Fetching data for 274: margate
# Fetching data for 275: touros
# Fetching data for 276: port hawkesbury
# Fetching data for 277: ivankiv
# Fetching data for 278: benjamin constant
# Fetching data for 279: haikou
# Fetching data for 280: palora
# Fetching data for 281: nome
# Fetching data for 282: coahuayana
# Fetching data for 283: paoua
# Fetching data for 284: bambous virieux
# Fetching data for 285: pacific grove
# Fetching data for 286: makakilo city
# Fetching data for 287: anahuac
# Fetching data for 288: aguilas
# Fetching data for 289: prainha
# Fetching data for 290: guamuchil
# Fetching data for 291: birjand
# Fetching data for 292: waitati
# Fetching data for 293: middelburg

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_list = {'latitude':lat,'temperature':temp,'cloud':cloudiness,'windspeed':windspeed,'humidity':humidity,'long':long,'cityname':city_name,'country':country}
weather_df = pd.DataFrame(weather_list)
weather_df.to_csv(output_data_file, encoding='utf-8', index=False)

# %%
weather_df

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot for Latitude and Temperature
plt.scatter(weather_df["latitude"], weather_df["temperature"], marker = "o", facecolor = "red", edgecolor="blue")
plt.title("City Latitude vs. Max Temperature %s" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (degree F)")
plt.grid()
plt.savefig("Output_data/Images/temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude and humidity
plt.scatter(weather_df["latitude"], weather_df["humidity"], marker = "o", facecolor = "blue", edgecolor="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("Output_data/Images/humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["latitude"], weather_df["cloud"], marker = "o", facecolor = "navy", edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs Cloudiness (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("Output_data/Images/cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["latitude"], weather_df["windspeed"], marker = "o", facecolor = "green", edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Speed (mph)")
plt.title("Latitude vs Wind Speed (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("Output_data/Images/windspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem_df = weather_df.loc[weather_df['latitude']>0]
south_hem_df = weather_df.loc[weather_df['latitude']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
x_values = north_hem_df['latitude']
y_values = north_hem_df['temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=15,color="black")

plt.xlim(0,80)
plt.ylim(0,100)

plt.title("Latitude vs Temperature \n(Northern Hemisphere)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_northernhemisphere_temp_vs_latitude.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
x_values = south_hem_df['latitude']
y_values = south_hem_df['temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="black")

plt.xlim(-60,0,10)
plt.ylim(0,100)

plt.title("Latitude vs Temperature (Southern Hemisphere)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_southernhemisphere_temp_vs_latitude.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Latitude vs humidity of City
x_values = north_hem_df['latitude']
y_values = north_hem_df['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")

plt.xlim(0,80)
plt.ylim(0,100)

plt.title("Latitude vs Humidity(%) \n(Northern Hemisphere)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_northernhemisphere_humidity_vs_latitude.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Latitude vs humidity of City
x_values = south_hem_df['latitude']
y_values = south_hem_df['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,20),fontsize=15,color="red")

plt.title("Latitude vs Humidity(%) \n(Southern Hemisphere)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_southernhemisphere_humidity_vs_latitude.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Latitude vs Cloudiness of City
x_values = north_hem_df['latitude']
y_values = north_hem_df['cloud']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")

plt.xlim(0,80)
plt.ylim(0,100)

plt.title("Latitude vs Cloudiness(%) \n(Northern Hemisphere)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_northernhemisphere_latitude_vs_cloudiness.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Latitude vs Cloudiness of City
x_values = south_hem_df['latitude']
y_values = south_hem_df['cloud']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")


plt.title("Latitude vs Cloudiness(%) \n(Southern Hemisphere)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_southernhemisphere_latitude_vs_cloudiness.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Latitude vs Cloudiness of City
x_values = north_hem_df['latitude']
y_values = north_hem_df['windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,15),fontsize=15,color="red")


plt.title("Latitude vs Windspeed(mph) \n(Northern Hemisphere)")
plt.ylabel("Windspeed(mph)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_northernhemisphere_latitude_vs_windspeed.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Latitude vs Cloudiness of City
x_values = south_hem_df['latitude']
y_values = south_hem_df['windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")


plt.title("Latitude vs Windspeed(mph) \n(Southern Hemisphere)")
plt.ylabel("Windspeed(mph)")
plt.xlabel("Latitude")

#save scatter plot chart
plt.savefig("Output_data/Images/regression_southernhemisphere_latitude_vs_windspeed.png")
